# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.callbacks import EarlyStopping,TensorBoard
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder,scale
import pickle
import numpy as np
from keras import backend as K
import time
from os import path
# Out:
# Using TensorFlow backend.

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
#print(train_df.head())
train_X = train_df.drop(columns=['Severity'])
train_y = train_df['Severity']
test_X = test_df.drop(columns=['Severity'])
test_y = test_df['Severity']


if path.exists('le.txt'):
    le=pickle.load(open('le.pickle','rb'))
else:
    le = LabelEncoder()
    le.fit(train_y)
    pickle.dump(le,open("le.pickle","wb"))

train_X=scale(train_X)
train_y = le.transform(train_y)
test_X=scale(test_X)
test_y = le.transform(test_y)

# %%
dense_layers = [3,5,7,8]
layer_sizes = [128]
#get number of columns in training data
n_cols = train_X.shape[1]
scores=[]
for dense_layer in dense_layers:
    for layer_size in layer_sizes:   
         NAME = "{}-nodes-{}-dense-{}".format(layer_size, dense_layer, int(time.time()))
         
         
         model = Sequential()

         #add layers to model

         model.add(Dense(250, activation='relu', input_shape=(n_cols,)))

         for i in range(dense_layer):
            model.add(Dense(layer_size, activation='relu'))
            model.add(Dropout(0.3))
        
         model.add(Dense(4, activation='sigmoid'))

         #compile model using accuracy to measure model performance
         tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
         model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

         #set early stopping monitor so the model stops training when it won't improve anymore
         early_stopping_monitor = EarlyStopping(patience=3)

         model.fit(train_X, train_y, validation_split=0.2, epochs=500, callbacks=[tensorboard,early_stopping_monitor])

         print(NAME)
         pickle.dump(model,open('models/'+NAME+'.pickle',"wb"))
         print('SCORE:',model.evaluate(test_X, test_y, verbose=0))
         scores.append(model.evaluate(test_X, test_y, verbose=0))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0407 18:27:52.643130 13696 deprecation.py:506] From c:\program files\python37\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# W0407 18:27:53.625186 13696 deprecation.py:323] From c:\program files\python37\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0407 18:27:54.198219 13696 module_wrapper.py:139] From c:\program files\python37\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W0407 18:27:54.206220 13696 module_wrapper.py:139] From c:\program files\python37\lib\site-packages\keras\callbacks\tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0407 18:27:54.208220 13696 module_wrapper.py:139] From c:\program files\python37\lib\site-packages\keras\callbacks\tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Train on 6400 samples, validate on 1601 samples
# Epoch 1/500
# 6400/6400 [==============================] - 1s 132us/step - loss: 0.9817 - accuracy: 0.5653 - val_loss: 0.5100 - val_accuracy: 0.8145
# W0407 18:27:55.255280 13696 module_wrapper.py:139] From c:\program files\python37\lib\site-packages\keras\callbacks\tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
# Epoch 2/500
# 6400/6400 [==============================] - 1s 102us/step - loss: 0.4961 - accuracy: 0.8188 - val_loss: 0.3385 - val_accuracy: 0.8932
# Epoch 3/500
# 6400/6400 [==============================] - 1s 96us/step - loss: 0.3544 - accuracy: 0.8822 - val_loss: 0.2587 - val_accuracy: 0.9200
# Epoch 4/500
# 6400/6400 [==============================] - 1s 93us/step - loss: 0.2988 - accuracy: 0.9036 - val_loss: 0.2551 - val_accuracy: 0.9157
# Epoch 5/500
# 6400/6400 [==============================] - 1s 91us/step - loss: 0.2732 - accuracy: 0.9119 - val_loss: 0.2384 - val_accuracy: 0.9157
# Epoch 6/500
# 6400/6400 [==============================] - 1s 95us/step - loss: 0.2551 - accuracy: 0.9177 - val_loss: 0.2193 - val_accuracy: 0.9313
# Epoch 7/500
# 6400/6400 [==============================] - 1s 99us/step - loss: 0.2461 - accuracy: 0.9203 - val_loss: 0.2437 - val_accuracy: 0.9219
# Epoch 8/500
# Epoch 9/500
# 6400/6400 [==============================] - 1s 165us/step - loss: 0.2912 - accuracy: 0.9131 - val_loss: 0.2204 - val_accuracy: 0.9350
# Epoch 10/500
# 6400/6400 [==============================] - 1s 159us/step - loss: 0.2905 - accuracy: 0.9106 - val_loss: 0.2338 - val_accuracy: 0.9263
# Epoch 11/500
# 6400/6400 [==============================] - 1s 169us/step - loss: 0.2594 - accuracy: 0.9236 - val_loss: 0.2442 - val_accuracy: 0.9307
# Epoch 12/500
# 6400/6400 [==============================] - 1s 163us/step - loss: 0.2637 - accuracy: 0.9212 - val_loss: 0.2237 - val_accuracy: 0.9288
# 128-nodes-7-dense-1586264291
# SCORE: [0.2036457518567557, 0.9374687075614929]
# Train on 6400 samples, validate on 1601 samples
# Epoch 1/500
# 6400/6400 [==============================] - 2s 251us/step - loss: 1.2119 - accuracy: 0.4011 - val_loss: 0.9857 - val_accuracy: 0.5821
# Epoch 2/500
# 6400/6400 [==============================] - 1s 170us/step - loss: 0.8352 - accuracy: 0.6672 - val_loss: 0.6143 - val_accuracy: 0.7976
# Epoch 3/500
# 6400/6400 [==============================] - 1s 170us/step - loss: 0.5995 - accuracy: 0.7742 - val_loss: 0.3662 - val_accuracy: 0.8588
# Epoch 4/500
# 6400/6400 [==============================] - 1s 170us/step - loss: 0.4631 - accuracy: 0.8342 - val_loss: 0.3137 - val_accuracy: 0.9107
# Epoch 5/500
# 6400/6400 [==============================] - 1s 169us/step - loss: 0.4039 - accuracy: 0.8608 - val_loss: 0.3187 - val_accuracy: 0.9007
# Epoch 6/500
# 6400/6400 [==============================] - 1s 188us/step - loss: 0.3646 - accuracy: 0.8822 - val_loss: 0.2664 - val_accuracy: 0.9200
# Epoch 7/500
# 6400/6400 [==============================] - 1s 173us/step - loss: 0.3540 - accuracy: 0.8853 - val_loss: 0.2806 - val_accuracy: 0.9082
# Epoch 8/500
# 6400/6400 [==============================] - 1s 170us/step - loss: 0.3230 - accuracy: 0.8984 - val_loss: 0.2715 - val_accuracy: 0.9275
# Epoch 9/500
# 6400/6400 [==============================] - 1s 172us/step - loss: 0.3207 - accuracy: 0.9045 - val_loss: 0.2355 - val_accuracy: 0.9375
# Epoch 10/500
# 6400/6400 [==============================] - 1s 172us/step - loss: 0.3074 - accuracy: 0.9084 - val_loss: 0.2569 - val_accuracy: 0.9188
# Epoch 11/500
# 6400/6400 [==============================] - 1s 169us/step - loss: 0.2870 - accuracy: 0.9128 - val_loss: 0.2413 - val_accuracy: 0.9213
# Epoch 12/500
# 6400/6400 [==============================] - 1s 174us/step - loss: 0.2922 - accuracy: 0.9128 - val_loss: 0.2474 - val_accuracy: 0.9207
# 128-nodes-8-dense-1586264308
# SCORE: [0.2174410434172355, 0.9359679818153381]

# %%
from sklearn.metrics import classification_report as cr
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier

# %%
ob1=KNeighborsClassifier(3)
ob2=SVC(kernel="rbf", C=0.025, probability=True)
ob3=DecisionTreeClassifier()
ob4=RandomForestClassifier()
ob5=AdaBoostClassifier()
ob6=GradientBoostingClassifier()
ob7=XGBClassifier()

algorithms = [('knc', ob1),('svc', ob2),('dtc', ob3),('rcf', ob4),('abc', ob5),('gbc', ob6),('xgbc', ob7)]
classifiers = [
KNeighborsClassifier(3),
SVC(kernel="rbf", C=0.025, probability=True),
DecisionTreeClassifier(),
RandomForestClassifier(),
AdaBoostClassifier(),
GradientBoostingClassifier(),
XGBClassifier(),
VotingClassifier(algorithms)
]

# %%
x=train_X
y=train_y
#test_X
#test_y
k_list = [2,3,4,5]
for classifier in classifiers:
    accu = []
    pipe = Pipeline(steps=[('classifier', classifier)])
    
    for j in k_list:
        accuracy = []
        kf = KFold(n_splits=j,shuffle=True)
        for (train, test), i in zip(kf.split(x, y), range(5)):
            pipe.fit(x[train], y[train])
            ypred=pipe.predict(x[test])
            accuracy.append(accuracy_score(y[test],ypred))
            #print(classifier)
            #print(cr(y[test],ypred))
        #print("\nList of Accuracies:",accuracy,"\n")
        acc = sum(accuracy)/j
        name=str(classifier).split('(')[0]
        print(name,"Average Accuracy:",acc,"\n")
        accu.append(acc)
    print("____________________________________________________________________________________________________________________________")
# Out:
# KNeighborsClassifier Average Accuracy: 0.562679673831542
#
# KNeighborsClassifier Average Accuracy: 0.5853018372703412
#
# KNeighborsClassifier Average Accuracy: 0.5884271614192903
#
# KNeighborsClassifier Average Accuracy: 0.5870501249219238
#
# ____________________________________________________________________________________________________________________________
# SVC Average Accuracy: 0.4137002624343914
#
# SVC Average Accuracy: 0.4583177102862142
#
# SVC Average Accuracy: 0.4840662168915542
#
# SVC Average Accuracy: 0.4896922236102436
#
# ____________________________________________________________________________________________________________________________
# DecisionTreeClassifier Average Accuracy: 0.8861391527118221
#
# DecisionTreeClassifier Average Accuracy: 0.9026371703537057
#
# DecisionTreeClassifier Average Accuracy: 0.9041381184407796
#
# DecisionTreeClassifier Average Accuracy: 0.9026363210493441
#
# ____________________________________________________________________________________________________________________________
# RandomForestClassifier Average Accuracy: 0.8741400587353162
#
# RandomForestClassifier Average Accuracy: 0.8872640919885014
#
# RandomForestClassifier Average Accuracy: 0.896640492253873
#
# RandomForestClassifier Average Accuracy: 0.9022624921923799
#
# ____________________________________________________________________________________________________________________________
# AdaBoostClassifier Average Accuracy: 0.5439311734566359
#
# AdaBoostClassifier Average Accuracy: 0.5470566179227596
#
# AdaBoostClassifier Average Accuracy: 0.5459322838580709
#
# AdaBoostClassifier Average Accuracy: 0.5515530137414115
#
# ____________________________________________________________________________________________________________________________
# GradientBoostingClassifier Average Accuracy: 0.849894057735566
#
# GradientBoostingClassifier Average Accuracy: 0.8587676540432447
#
# GradientBoostingClassifier Average Accuracy: 0.8650168040979511
#
# GradientBoostingClassifier Average Accuracy: 0.8680172548407243
#
# ____________________________________________________________________________________________________________________________
# XGBClassifier Average Accuracy: 0.9411321857035742
#
# XGBClassifier Average Accuracy: 0.9448818897637795
#
# XGBClassifier Average Accuracy: 0.9486307471264368
#
# XGBClassifier Average Accuracy: 0.9520065584009995
#
# ____________________________________________________________________________________________________________________________
# VotingClassifier Average Accuracy: 0.882638871532117
#
# VotingClassifier Average Accuracy: 0.8882639670041245
#
# VotingClassifier Average Accuracy: 0.8938862443778111
#
# VotingClassifier Average Accuracy: 0.8976384291068082
#
# ____________________________________________________________________________________________________________________________

# %%
print('Neural network scores:')
for i in scores:
    print('accuracy:',i[1])
# Out:
# Neural network scores:
# accuracy: 0.9299649596214294
# accuracy: 0.9309654831886292
# accuracy: 0.9374687075614929
# accuracy: 0.9359679818153381
